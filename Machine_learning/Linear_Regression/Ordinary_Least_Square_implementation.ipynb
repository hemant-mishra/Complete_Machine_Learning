# %%
# ordinary Least Square method
# y=mx+c
# b=y(bar)-mx(bar)
# m=summition(i=1 to n)(xi-x(bar))*(yi-y(bar))/summition(i=1 to n)(xi-x(bar))**2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\heman\Downloads\placement (1).csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LR.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# array([2.78031348])

# %%
y_pred=LR.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# print(mean_absolute_error(y_test,y_pred))
# print(mean_squared_error(y_test,y_pred))
# print(np.sqrt(mean_squared_error(y_test,y_pred)))
# print(r2_score(y_test,y_pred))

# %%
class MeraLR:
    def __init__(self):
        self.m=None
        self.b=None
        
    def fit(self,x_train,y_train):
        num=0
        denm=0
        for i in range(x_train.shape[0]):
            num= num + ((x_train[i]-x_train.mean())*(y_train[i]-y_train.mean()))
            denm= denm + (x_train[i]-x_train.mean())**2
        self.m=num/denm
        self.b= y_train.mean()-(self.m*x_train.mean())
        print(self.m)
        print(self.b)
    def predict(self, x_test_value):
        print(self.m*x_test_value +self.b)

# %%
lr=MeraLR()

# %%
x=df.iloc[:,0].values
y=df.iloc[:,1].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr.fit(x_train,y_train)
# Out:
# 0.5742564727019197
# -1.0270069374542108

# %%
lr.predict(x_test[0])
# Out:
# 2.7803134765595168

# %%
x_train.shape[0]
# Out:
# 160
