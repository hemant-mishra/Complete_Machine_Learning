# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=100,n_features=2, n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,hypercube=False,class_sep=5)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1],c=y,cmap="winter",s=100)
plt.show()

# %%
def step(z):
    if z>0:
        return 1
    else:
        return 0

# %%
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights=np.ones(x.shape[1])
    lr=0.1
    # print(weights)
    for i in range(1000):
        j=np.random.randint(0,x.shape[0])
        y_hat=step(np.dot(x[j],weights))
        weights=weights  +lr*(y[j]-y_hat)*x[j]
        # print(weights)
    return weights[0], weights[1:]

# %%
intercept_,coef_=perceptron(x,y)

# %%
print(intercept_)
print(coef_)
# Out:
# 1.3000000000000003
# [ 0.47294176 -0.0288593 ]

# %%
m=-(coef_[0]/coef_[1])
b= -(intercept_/coef_[1])

# %%
x_input=np.linspace(-3,3,100)
y_output=m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_output,color="red",linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap="winter",s=10)
plt.ylim(-5,5)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()

# %%
LR.fit(x,y)
# Out:
# LogisticRegression()

# %%
LR.coef_
# Out:
# array([[ 1.69477691, -0.3346162 ]])

# %%
LR.intercept_
# Out:
# array([1.67921854])

# %%
m1=-(LR.coef_[0][0]/LR.coef_[0][1])
b1= -(LR.intercept_/LR.coef_[0][1])

# %%
print(m1)
print(b1)
# Out:
# 5.0648381739957475
# [5.01834199]

# %%
x_input1=np.linspace(-3,3,100)
y_output1=m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_output,color="red",linewidth=5)
plt.plot(x_input1,y_output1,color="black",linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap="winter",s=10)
plt.ylim(-5,5)
plt.show()
