# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\heman\Downloads\placement.csv")

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 819  6.93                  10.0       0
# 842  7.33                  14.0       1
# 198  8.29                  44.0       1
# 568  8.13                   4.0       0
# 349  8.12                  16.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df["cgpa"],kde=True)
plt.subplot(1,2,2)
sns.histplot(df["placement_exam_marks"],kde=True)
# Out:
# <AxesSubplot:xlabel='placement_exam_marks', ylabel='Count'>

# %%
sns.boxplot(df["placement_exam_marks"])
# Out:
# <AxesSubplot:ylabel='placement_exam_marks'>

# %%
q1=df["placement_exam_marks"].quantile(0.25)
q2=df["placement_exam_marks"].quantile(0.50)
q3=df["placement_exam_marks"].quantile(0.75)

# %%
IQR=q3-q1

# %%
print(q1)
print(q2)
print(q3)
print(IQR)
# Out:
# 17.0
# 28.0
# 44.0
# 27.0

# %%
upper_limit=q3+1.5*IQR
lower_limit=q1-1.5*IQR

# %%
print(upper_limit)
print(lower_limit)
# Out:
# 84.5
# -23.5

# %%
#trimming

# %%
df1=df[(df["placement_exam_marks"]>-23.5)&(df["placement_exam_marks"]<84.5)]

# %%
df1
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [985 rows x 3 columns]

# %%
sns.boxplot(df1["placement_exam_marks"])
# Out:
# <AxesSubplot:ylabel='placement_exam_marks'>

# %%
df["placement_exam_marks"]=np.where(df["placement_exam_marks"]>84.5,84.5,np.where(df["placement_exam_marks"]<-23.5,-23.5,df["placement_exam_marks"]))

# %%
sns.boxplot(df["placement_exam_marks"])
# Out:
# <AxesSubplot:ylabel='placement_exam_marks'>

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df["cgpa"],kde=True)
plt.subplot(1,2,2)
sns.histplot(df["placement_exam_marks"],kde=True)
# Out:
# <AxesSubplot:xlabel='placement_exam_marks', ylabel='Count'>
