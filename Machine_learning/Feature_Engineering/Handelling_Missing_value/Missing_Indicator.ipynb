# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\heman\Downloads\train.csv",usecols=["Survived","Age","Fare"])

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.impute import MissingIndicator

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=["Survived"],axis=1),df["Survived"],test_size=0.2,random_state=42)

# %%
x_train.isnull().sum()
# Out:
# Age     140
# Fare      0
# dtype: int64

# %%
x_test.isnull().sum()
# Out:
# Age     37
# Fare     0
# dtype: int64

# %%
SI=SimpleImputer()

# %%
x_train_trf=SI.fit_transform(x_train)
x_test_trf=SI.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LG=LogisticRegression()
LG.fit(x_train_trf,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=LG.predict(x_test_trf)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6480446927374302

# %%
# specifying Missing indicator

# %%
SIM=SimpleImputer(add_indicator=True)

# %%
x_train_SIM=SIM.fit_transform(x_train)
x_test_SIm=SIM.transform(x_test)

# %%
x_train_SIM
# Out:
# array([[ 45.5   ,  28.5   ,   0.    ],
#        [ 23.    ,  13.    ,   0.    ],
#        [ 32.    ,   7.925 ,   0.    ],
#        ...,
#        [ 41.    ,  14.1083,   0.    ],
#        [ 14.    , 120.    ,   0.    ],
#        [ 21.    ,  77.2875,   0.    ]])

# %%
x_test_SIm
# Out:
# array([[ 29.49884615,  15.2458    ,   1.        ],
#        [ 31.        ,  10.5       ,   0.        ],
#        [ 20.        ,   7.925     ,   0.        ],
#        [  6.        ,  33.        ,   0.        ],
#        [ 14.        ,  11.2417    ,   0.        ],
#        [ 26.        ,  78.85      ,   0.        ],
#        [ 29.49884615,   7.75      ,   1.        ],
#        [ 16.        ,  18.        ,   0.        ],
#        [ 16.        ,   7.75      ,   0.        ],
#        [ 19.        ,  26.2833    ,   0.        ],
#        [ 37.        ,  53.1       ,   0.        ],
#        [ 44.        ,   8.05      ,   0.        ],
#        [ 29.49884615,  25.4667    ,   1.        ],
#        [ 30.        ,   7.225     ,   0.        ],
#        [ 36.        ,  13.        ,   0.        ],
#        [ 16.        ,  39.4       ,   0.        ],
#        [ 42.        ,  52.5542    ,   0.        ],
#        [ 29.49884615,   7.8292    ,   1.        ],
# ...

# %%
LGS=LogisticRegression()

# %%
LGS.fit(x_train_SIM,y_train)
# Out:
# LogisticRegression()

# %%
Y_pred_sim=LGS.predict(x_test_SIm)

# %%
print(accuracy_score(y_test,Y_pred_sim))
# Out:
# 0.6368715083798883

# %%
mi=MissingIndicator()

# %%
mi.fit(x_train)
# Out:
# MissingIndicator()

# %%
x_train_mi=mi.transform(x_train)

# %%
x_test_mi=mi.transform(x_test)

# %%
x_train_mi
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
# ...

# %%
x_test_mi
# Out:
# array([[ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
x_train["missing_indicator"]=x_train_mi
x_test["missing_indicator"]=x_test_mi

# %%
x_train.sample(5)
# Out:
#       Age     Fare  missing_indicator
# 297   2.0  151.550              False
# 741  36.0   78.850              False
# 366  60.0   75.250              False
# 728  25.0   26.000              False
# 719  33.0    7.775              False

# %%
x_test.sample(5)
# Out:
#       Age     Fare  missing_indicator
# 837   NaN   8.0500               True
# 292  36.0  12.8750              False
# 670  40.0  39.0000              False
# 493  71.0  49.5042              False
# 854  44.0  26.0000              False
