# %%
import numpy as np
import pickle

# %%
model=pickle.load(open("Titanic_model_pipeline.pkl","rb"))

# %%
input_array=np.array([3, 'female', 31.0,10.5,'S',0],dtype=object).reshape(1,6)

# %%
model.predict(input_array)
# Out:
# C:\Users\GR0012AU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\GR0012AU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
