# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test,LR.predict(x_test)))
# Out:
# 2900.1732878832318

# %%
class GDregression:
    def __init__(self,learning_rate=0.01,epochs=100):
        self.learning_rate=learning_rate
        self.epochs=epochs
        self.intercept_=None
        self.coef_=None
    def fit(self,x_train,y_train):
        self.coef_=np.ones(x_train.shape[1])
        self.intercept_=0
        
        for i in range(self.epochs):
            
            y_hat=np.dot(x_train,self.coef_) + self.intercept_
            slope_intercept = -2*np.mean(y_train - y_hat)
            self.intercept_=self.intercept_ - self.learning_rate*(slope_intercept)
            
            slope_coef_= -2* np.dot((y_train - y_hat),x_train)/x_train.shape[0]
            self.coef_=self.coef_ - self.learning_rate*(slope_coef_)

        print(self.coef_,self.intercept_)
    
    def predict(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
lr=GDregression()

# %%
lr.fit(x_train,y_train)
# Out:
# [ 2.58205922  1.0594131   5.63996055  4.47533637  2.36970912  2.00365401
#  -1.91538251  4.16500591  5.22506959  4.14890553] 133.3270222890049

# %%
lr.predict(x_test)
# Out:
# array([134.09126541, 133.3582392 , 134.05770934, 135.88325268,
#        133.57653982, 133.24172746, 135.01759184, 134.89508018,
#        132.39579365, 133.19673472, 132.57101357, 132.53673826,
#        131.23079263, 134.72196588, 132.79320153, 132.74285063,
#        134.96670569, 135.33362035, 133.06746122, 134.63844222,
#        133.40435646, 132.65721345, 132.02175416, 134.25194299,
#        132.86114508, 133.647289  , 133.84623087, 133.69215527,
#        131.32801193, 133.4577006 , 133.70811939, 132.23117525,
#        133.2702508 , 134.0420855 , 134.08237794, 134.28114098,
#        133.21419901, 133.54630792, 134.18892117, 131.7784507 ,
#        132.34493871, 133.08630062, 133.13816038, 134.08853013,
#        133.72799091, 131.97836173, 131.75938585, 132.1527994 ,
#        131.55941628, 132.84385182, 132.37907032, 131.49694081,
#        133.14942597, 132.56206996, 134.46812649, 132.6814695 ,
#        132.75104159, 133.85345566, 132.38708589, 131.561968  ,
# ...
