# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes

# %%
x,y=load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
print(mean_squared_error(y_test,LR.predict(x_test)))
# Out:
# 2767.2612360205508

# %%
class SGD:
    def __init__(self,learning_rate=0.01,epochs=100):
        self.learning_rate=learning_rate
        self.epochs=epochs
        self.intecept_=None
        self.coef_=None
        
    def fit(self,x_tarin,y_train):
        self.coef_=np.ones(x_train.shape[1])
        self.intercept_=0
        
        for i in range(self.epochs):
            
            idx=np.random.randint(0,x_train.shape[0])
            y_hat=np.dot(x_train[idx],self.coef_) + self.intercept_
            
            slope_intercept = -2*(y_train[idx] - y_hat)
            self.intercept_=self.intercept_ - self.learning_rate*(slope_intercept)
            
            slope_coef_ = -2* np.dot((y_train[idx] - y_hat),x_train[idx])
            self.coef_ = self.coef_ - self.learning_rate*(slope_coef_)

        print(self.coef_,self.intercept_)
    
    def predict(self,x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
sgd=SGD()

# %%
sgd.fit(x_train,y_train)
# Out:
# [ 1.69563394  1.17824754  5.14951969  5.01078405  2.63400826  1.83647244
#  -2.22856432  4.41393578  6.33076636  6.42314213] 141.18693726585914

# %%
sgd.predict(x_test)
# Out:
# array([141.93879417, 141.03607895, 141.9167959 , 143.98498023,
#        141.4248525 , 141.06660116, 142.94365967, 143.01475422,
#        140.39095741, 141.05653053, 140.33245383, 140.26927431,
#        138.91405657, 142.87731234, 140.76066451, 140.63970386,
#        143.06306824, 143.36957872, 140.97516549, 142.57299112,
#        141.33868396, 140.28045213, 139.82620172, 142.17446542,
#        140.6671217 , 141.49560928, 141.62167824, 141.5467949 ,
#        139.02139866, 141.35472006, 141.46570217, 140.04035279,
#        141.12251082, 142.03028307, 141.88676972, 142.23110465,
#        141.16294061, 141.50565054, 142.242898  , 139.34203545,
#        140.22040773, 140.87871149, 140.88050582, 142.01125355,
#        141.70081902, 139.55627619, 139.57264799, 139.93774707,
#        139.23258849, 140.64272278, 140.02886908, 139.18364368,
#        140.7526254 , 140.35787998, 142.42087477, 140.29515451,
#        140.61069874, 141.65605633, 140.09800057, 139.34503532,
#        142.19093811, 141.19699075, 140.56825986, 141.10921446,
#        140.74248658, 141.87251474, 142.22441576, 141.42251139,
#        139.43183935, 141.01729741, 141.58127292, 142.61655061,
#        143.53183074, 140.75908408, 139.63307295, 141.87655315,
#        142.85255979, 141.6320029 , 141.79771294, 141.92951128,
#        140.23014605, 139.80094919, 139.25887599, 139.9564461 ,
#        140.47633929, 139.76485604, 138.83959449, 139.0564552 ,
#        140.46754673])
